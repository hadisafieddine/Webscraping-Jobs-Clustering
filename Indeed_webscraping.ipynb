# %% [markdown]
# # Web Scraping - Indeed.com
# General steps for Web Scraping
# 1. Check whether the website allows web scraping
# 2. Obtain the source code (HTML File) by using the website URL
# 3. Download the website content
# 4. Parse the content using keywords tags for elements of interest
# 5. Extract relevant data/features
# 6. Organize raw data in structured format (e.g., CSV)

# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By

# %% [markdown]
# ### Path to webdriver (Firefox, Chrome)

# %%
# Ensure that the driver path is correct before running this script.
# Microsoft Windows
driver_path = "./drivers/windows/geckodriver.exe"
# Linux
#driver_path = "./drivers/linux/geckodriver"
driver = webdriver.Firefox(executable_path=driver_path)
# Out:
# C:\Users\roman\AppData\Local\Temp\ipykernel_21348\2787909294.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path=driver_path)

# %% [markdown]
# ### Define position and location

# %%
## Enter a job position
position = "data scientist"
## Enter a location (City, State or Zip or remote)
locations = "remote"

def get_url(position, location):
    url_template = "https://www.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])

# %% [markdown]
# ### Scrape job postings

# %%
## Number of postings to scrape
postings = 100

jn=0
for i in range(0, postings, 10):
    driver.get(url + "&start=" + str(i))
    driver.implicitly_wait(3)

    jobs = driver.find_elements(By.CLASS_NAME, 'job_seen_beacon')

    for job in jobs:
        result_html = job.get_attribute('innerHTML')
        soup = BeautifulSoup(result_html, 'html.parser')
        
        jn += 1
        
        liens = job.find_elements(By.TAG_NAME, "a")
        links = liens[0].get_attribute("href")
        
        title = soup.select('.jobTitle')[0].get_text().strip()
        company = soup.select('.companyName')[0].get_text().strip()
        location = soup.select('.companyLocation')[0].get_text().strip()
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
        try:
            rating = soup.select('.ratingNumber')[0].get_text().strip()
        except:
            rating = 'NaN'
        try:
            date = soup.select('.date')[0].get_text().strip()
        except:
            date = 'NaN'
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''
       
        dataframe = pd.concat([dataframe, pd.DataFrame([{'Title': title,
                                          "Company": company,
                                          'Location': location,
                                          'Rating': rating,
                                          'Date': date,
                                          "Salary": salary,
                                          "Description": description,
                                          "Links": links}])], ignore_index=True)
        print("Job number {0:4d} added - {1:s}".format(jn,title))
# Out:
# Job number    1 added - Data Scientist
# Job number    2 added - Data Scientist
# Job number    3 added - Data Scientist
# Job number    4 added - Data Scientist (REMOTE)
# Job number    5 added - Data Scientist
# Job number    6 added - Data Scientist
# Job number    7 added - Data Analyst - Sr Specialist
# Job number    8 added - Network Data Scientist
# Job number    9 added - Data Scientist
# Job number   10 added - Data Scientist
# Job number   11 added - Data Scientist
# Job number   12 added - Data Scientist
# Job number   13 added - Associate Data Scientist
# Job number   14 added - Data Scientist
# Job number   15 added - Data Scientist
# Job number   16 added - Data Scientist
# Job number   17 added - Data Scientist
# Job number   18 added - Jr. Data Scientist
# Job number   19 added - Junior Data Scientist
# Job number   20 added - Data Scientist
# Job number   21 added - Data Scientist, Baseball Research & Development
# Job number   22 added - Senior Data Scientist (Remote)
# Job number   23 added - Data Scientist
# Job number   24 added - Data Scientist
# Job number   25 added - Data Scientist
# Job number   26 added - Climate Data Scientist
# Job number   27 added - Data Scientist
# Job number   28 added - Senior Data Analyst
# Job number   29 added - Data Scientist
# Job number   30 added - Data Scientist
# Job number   31 added - Data Scientist
# Job number   32 added - Data Scientist
# Job number   33 added - Data Scientist (Remote)
# Job number   34 added - Data Scientist
# Job number   35 added - Data Scientist
# Job number   36 added - Data Scientist Co-Op (Spring 2023)
# Job number   37 added - Climate Data Scientist
# Job number   38 added - Data Scientist - HealthTech Algorithms
# Job number   39 added - Data Scientist or Bioinformatician (remote)
# Job number   40 added - Data Engineer/Data Scientist
# Job number   41 added - Associate Data Scientist
# Job number   42 added - Hiring for Data Scientist remote position :: Fulltime
# Job number   43 added - Data Scientist
# Job number   44 added - Data Scientist
# Job number   45 added - Oraacle Data Scientist
# Job number   46 added - Data Scientist
# Job number   47 added - Data Scientist
# Job number   48 added - Data Scientist
# Job number   49 added - Trainee Data Scientist
# Job number   50 added - Data Scientist, Baseball Research & Development
# Job number   51 added - NLP Data Scientist
# Job number   52 added - Data Scientist
# Job number   53 added - Data Scientist
# Job number   54 added - Data Scientist, Product
# Job number   55 added - Senior Data Scientist
# Job number   56 added - Associate Data Scientist (REMOTE)
# Job number   57 added - Data Scientist and Analyst
# Job number   58 added - Data Scientist
# Job number   59 added - Data Scientist
# Job number   60 added - Senior Data Scientist (R-12988)
# Job number   61 added - (5) Data Analyst / Data Scientist
# Job number   62 added - Data Scientist
# Job number   63 added - Data Scientist
# Job number   64 added - Data Scientist, Creator Promotion
# Job number   65 added - Associate Data Scientist (Remote)
# Job number   66 added - Data Scientist
# Job number   67 added - Data Scientist
# Job number   68 added - Data Scientist, Analytics II #0000
# Job number   69 added - Data Scientist and Data Analytics
# Job number   70 added - Data Scientist
# Job number   71 added - Data Scientist
# Job number   72 added - Data Scientist
# Job number   73 added - Data Scientist I (Remote)
# Job number   74 added - Sr. Data Scientist
# Job number   75 added - Data Scientist-Mid
# Job number   76 added - Data Science Analytics Associate
# Job number   77 added - Data Engineer/Data Scientist
# Job number   78 added - Data Scientist, Finance
# Job number   79 added - Data Scientist (Remote)
# Job number   80 added - Software Engineer, Machine Learning Foundation
# Job number   81 added - Data Scientist Co-Op (Spring 2023)
# Job number   82 added - Data Scientist (NBA)
# Job number   83 added - Data Scientist
# Job number   84 added - Data Scientist|New brunswick,NJ
# Job number   85 added - Cummins Data Scientist: Neurodiversity Hiring Initiative
# Job number   86 added - Product Data Scientist
# Job number   87 added - Data Scientist, CV/NLP
# Job number   88 added - Data Scientist
# Job number   89 added - Associate Machine Learning Engineer (Remote)
# Job number   90 added - Data Scientist
# Job number   91 added - Data Scientist (Experimentation)
# Job number   92 added - Senior Data Scientist
# Job number   93 added - Data Scientist
# Job number   94 added - Data Scientist III
# Job number   95 added - Senior Data Analyst
# Job number   96 added - Data Scientist
# Job number   97 added - Research Mentor in Mathematical Model/Data Analysis/Robotics...
# Job number   98 added - Data Science Project Lead - Computer Vision and Deepfake
# Job number   99 added - Data Scientist
# Job number  100 added - Data Scientist
# Job number  101 added - Data Scientist - 100% Remote
# Job number  102 added - Data Scientist
# Job number  103 added - Data Scientist
# Job number  104 added - Data Analyst
# Job number  105 added - Data Scientist
# Job number  106 added - Data Scientist
# Job number  107 added - DATA SCIENTIST
# Job number  108 added - Associate Data Scientist
# Job number  109 added - Data Scientist (Remote)
# Job number  110 added - Senior Data Analyst
# Job number  111 added - Data Scientist
# Job number  112 added - Data Analyst/Scientist
# Job number  113 added - Reporting and Data Science Analyst
# Job number  114 added - Senior Data Scientist - Inference, Payments
# Job number  115 added - Data Scientist
# Job number  116 added - Data Scientist
# Job number  117 added - Data Scientist
# Job number  118 added - Algorithm Development Analyst / Data Scientist
# Job number  119 added - Data Scientist (AI/ML, AWS)
# Job number  120 added - Data Scientist
# Job number  121 added - Software Engineer - Machine Learning (Remote)
# Job number  122 added - Data Scientist
# Job number  123 added - Data Scientist (HEOR / RWE)
# Job number  124 added - Data Scientist
# Job number  125 added - Data Scientist - remote
# Job number  126 added - Clinical Data Scientist - Contract
# Job number  127 added - Data Scientist
# Job number  128 added - Data Scientist - 3 positions - 100% remote
# Job number  129 added - Data Scientist
# Job number  130 added - Data Scientist
# Job number  131 added - Data Scientist (Remote)
# Job number  132 added - Data Scientist
# Job number  133 added - Senior Data Scientist
# Job number  134 added - Data Scientist
# Job number  135 added - Sr. Data Scientist
# Job number  136 added - Data Scientist
# Job number  137 added - GCP Data Scientist/ML Engineer
# Job number  138 added - Data Specialist
# Job number  139 added - Data Visualization Specialist
# Job number  140 added - Senior Data Analyst
# Job number  141 added - Senior Data Analyst, Federal Civilian (remote)
# Job number  142 added - Data Science - General Interest - Talent Community
# Job number  143 added - Staff Data Scientist
# Job number  144 added - Data Science Content Creator
# Job number  145 added - Senior Data Scientist
# Job number  146 added - Data Science Engineer
# Job number  147 added - Data Scientist (Remote)
# Job number  148 added - Data Engineer with Machine learning Exp.
# Job number  149 added - Staff Data Scientist
# Job number  150 added - Machine Learning Data Scientist

# %%
driver.quit()

# %% [markdown]
# ### Scrape full job descriptions

# %%
Links_list = dataframe['Links'].tolist()
#Links_list

# %%
import random
import time

# %%
driver = webdriver.Firefox(executable_path=driver_path)
descriptions=[]
for i in Links_list:
    driver.get(i)
    driver.implicitly_wait(random.randint(3, 8))
    jd = driver.find_element(By.XPATH, '//div[@id="jobDescriptionText"]').text
    descriptions.append(jd)
    time.sleep(random.randint(5,10))

dataframe['Descriptions'] = descriptions
# Out:
# C:\Users\roman\AppData\Local\Temp\ipykernel_21348\3289258759.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path=driver_path)

# %%
driver.quit()

# %% [markdown]
# ### Save results

# %%
# Convert the dataframe to a csv file
date = datetime.today().strftime('%Y-%m-%d')
dataframe.to_csv(date + "_" + position + "_" + locations + ".csv", index=False)

# %%
dataframe
# Out:
#                                         Title                       Company  \
# 0                              Data Scientist  PNC Financial Services Group
# 1                              Data Scientist  PNC Financial Services Group
# 2                              Data Scientist   Shaw Industries Group, Inc.
# 3                              Data Scientist                       TVision
# 4                     Data Scientist (REMOTE)                    State Farm
# ..                                        ...                           ...
# 146                     Data Science Engineer                      Sensydia
# 147                   Data Scientist (Remote)                     Silverxis
# 148  Data Engineer with Machine learning Exp.        Albet Technologies LLC
# 149                      Staff Data Scientist       Mothership Technologies
# 150           Machine Learning Data Scientist                   AvaSure LLC
#
#                             Location Rating                       Date  \
# 0     Remote in Pittsburgh, PA 15222    3.5          PostedJust posted
# 1     Remote in Pittsburgh, PA 15222    3.5          PostedJust posted
# 2                             Remote    3.8                PostedToday
# 3         Remote in Boston, MA 02109    NaN   PostedPosted 18 days ago
# 4    Remote in Bloomington, IL 61701    3.7    PostedPosted 3 days ago
# ..                               ...    ...                        ...
# 146                           Remote    NaN   PostedPosted 10 days ago
# 147                           Remote    3.5  EmployerActive 5 days ago
# 148                           Remote    NaN   PostedPosted 12 days ago
# 149                           Remote    NaN  PostedPosted 30+ days ago
# 150      Remote in Belmont, MI 49306    3.7   PostedPosted 21 days ago
#
#                         Salary  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4    $69,115 - $169,250 a year
# ..                         ...
# 146       From $150,000 a year
# 147           From $25 an hour
# 148    $39.88 - $70.00 an hour
# 149                        NaN
# 150                        NaN
#
#                                            Description  \
# 0    Participates in the data gathering, data proce...
# 1    Participates in the data gathering, data proce...
# 2    Partner with data scientists across the enterp...
# 3    Your choice of comprehensive health benefits f...
# 4    Strong communication skills and the ability to...
# ..                                                 ...
# 146  A Master’s degree in engineering or science, a...
# 147  Familiarity with health/public health data.\nF...
# 148  Work alongside data scientists and product own...
# 149  Make significant and early contributions to th...
# 150  The machine learning data scientist provide bu...
#
#                                                  Links  \
# 0    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2    https://www.indeed.com/company/Shaw-Industries...
# 3    https://www.indeed.com/rc/clk?jk=6516da9c2bd81...
# 4    https://www.indeed.com/rc/clk?jk=4b1e7c89804f1...
# ..                                                 ...
# 146  https://www.indeed.com/company/Sensydia/jobs/D...
# 147  https://www.indeed.com/company/Silverxis/jobs/...
# 148  https://www.indeed.com/company/Albet-Technolog...
# 149  https://www.indeed.com/rc/clk?jk=2dca28ccb7473...
# 150  https://www.indeed.com/rc/clk?jk=2430871db04a2...
#
#                                           Descriptions
# 0    Job Profile\n\nPosition Overview\n\nAt PNC, ou...
# 1    Job Profile\n\nPosition Overview\n\nAt PNC, ou...
# 2    We are looking for a data scientist to join ou...
# 3    The Company\nTVision measures who watches TV a...
# 4    Overview:\nWe are not just offering a job but ...
# ..                                                 ...
# 146  About this role\nAre you interested in applyin...
# 147  Data Scientist (Remote)\nRICHMOND VA\nL*ocal c...
# 148  Candidates needs to be strong in spark, big da...
# 149  We are building the future of freight\n\nMothe...
# 150  We are seeking…\nA driven and talented team pl...
#
# [151 rows x 9 columns]
